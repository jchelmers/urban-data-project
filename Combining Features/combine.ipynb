# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import preprocessing
from sklearn import linear_model
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline

# %%
#read all
rating = pd.read_csv('Health_Insp_weather_loc_rating.csv', index_col=0) # change  
weather = pd.read_csv('health_inspect_cleaned_weather_added.csv', index_col=0) # change  
license = pd.read_csv('health_inspect_loc_license.csv', index_col=0) # change  
complaints = pd.read_csv('vdf_with_complaints.csv', index_col=0) # change     
complaints
# Out:
#           crit_violations  non_crit_violations earliest_inspection  \
# 40849391             11.0                  9.0          2013-09-05
# 41098999              6.0                  7.0          2013-08-05
# 41140992              3.0                  6.0          2014-08-07
# 41317857              6.0                  7.0          2014-03-21
# 41382811             10.0                 10.0          2014-05-28
# 41407455              3.0                  2.0          2013-05-30
# 41448651              6.0                  4.0          2014-05-12
# 41571277              6.0                  3.0          2013-10-28
# 41579510              2.0                  3.0          2014-05-15
# 41721226              5.0                  3.0          2014-07-17
# 30075445              8.0                  4.0          2013-08-14
# 30112340             14.0                 10.0          2014-06-05
# 40356018              1.0                  7.0          2013-06-05
# ...

# %% [markdown]
# ### combine below

# %%
vdf=weather 
vdf['food_poisoning_complaints']=complaints['food_poisoning_complaints'] 
vdf['food_establishment_complaints']=complaints['food_establishment_complaints']
vdf['electric_complaints']=complaints['electric_complaints']
vdf['safety_complaints']=complaints['safety_complaints'] 
vdf['rodent_complaints']=complaints['rodent_complaints'] 
vdf['dirty_conditions_complaints']=complaints['dirty_conditions_complaints'] 
vdf['general_complaints']=complaints['general_complaints'] 
vdf['missed_collection_complaints']=complaints['missed_collection_complaints'] 
vdf['police_matter_complaints']=complaints['police_matter_complaints']  
vdf['latitude'] =complaints['latitude'] 
vdf['longitude']=complaints['longitude'] 
vdf['liquor_license']=license['Liquor License']
vdf['sidewalk_license']=license['Sidewalk License']
vdf['names'] = rating['names']
vdf['search_info'] = rating['search_info']
vdf['rating'] = rating['rating']
vdf['rating_null'] = rating['rating_null']
vdf['rating_null_zip'] = rating['rating_null_zip']

# %%
vdf
# Out:
#           crit_violations  non_crit_violations earliest_inspection  \
# 30075445              8.0                  4.0          2013-08-14
# 30112340             14.0                 10.0          2014-06-05
# 30191841              4.0                  7.0          2013-07-22
# 40356018              1.0                  7.0          2013-06-05
# 40356151             13.0                  5.0          2014-04-11
# 40356483              9.0                 15.0          2013-07-09
# 40356731              4.0                  5.0          2013-07-10
# 40357217              2.0                  7.0          2013-06-19
# 40359705             15.0                  8.0          2014-11-29
# 40360045             17.0                 10.0          2014-10-20
# 40360076              2.0                  4.0          2015-01-22
# 40361322             10.0                  5.0          2014-10-07
# 40361606              4.0                  9.0          2013-11-14
# ...

# %%
#write in a file
vdf.to_csv('violations_all.csv')
