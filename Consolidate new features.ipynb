# %%
from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import preprocessing
from sklearn import linear_model
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier

from IPython.display import display
# %matplotlib inline
pd.options.display.max_rows = 10

# %% [markdown]
# ## Load the data
# ### Has had some preprocessing already, plus new features added from other datasets

# %%
violations_df = pd.read_csv('health_inspect_allFeatures.csv', index_col=0)

violations_df = violations_df[violations_df['complaints_null']==0] # Ignore the 23 restaurants we couldn't match with 311 data

display(violations_df)
# Out:
#           crit_violations  non_crit_violations earliest_inspection  \
# 30075445                8                    4           8/14/2013
# 30112340               14                   10            6/5/2014
# 30191841                4                    7           7/22/2013
# 40356018                1                    7            6/5/2013
# 40356151               13                    5           4/11/2014
# ...                   ...                  ...                 ...
# 50060427               10                    4            3/7/2017
# 50060496                7                    4           2/27/2017
# 50060695                7                    4            4/4/2017
# 50060807                2                    2            3/9/2017
# 50060808                8                    4            3/9/2017
#
#          latest_inspection second_latest_inspection  zipcode       boro  \
# 30075445         2/18/2016                 2/9/2015    10462      BRONX
# 30112340        10/27/2016                10/3/2016    11225   BROOKLYN
# 30191841         5/31/2016                9/21/2015    10019  MANHATTAN
# 40356018         5/16/2016                 6/5/2015    11224   BROOKLYN
# 40356151         5/14/2016                5/29/2015    11369     QUEENS
# ...                    ...                      ...      ...        ...
# 50060427          4/6/2017                3/20/2017    11217   BROOKLYN
# 50060496         3/31/2017                2/27/2017    11232   BROOKLYN
# 50060695         4/10/2017                 4/4/2017    11432     QUEENS
# 50060807         3/20/2017                 3/9/2017    10467      BRONX
# 50060808         3/27/2017                3/23/2017    11428     QUEENS
#
#                   cuisine                 address  num_inspections  \
# 30075445           Bakery    1007 MORRIS PARK AVE                5
# 30112340       Hamburgers     469 FLATBUSH AVENUE                9
# 30191841            Irish    351 WEST   57 STREET                5
# 40356018         American   2780 STILLWELL AVENUE                4
# 40356151         American  8825 ASTORIA BOULEVARD                7
# ...                   ...                     ...              ...
# 50060427  Bagels/Pretzels        73 LAFAYETTE AVE                3
# 50060496     Delicatessen            4102 3RD AVE                2
# 50060695            Pizza       16417 JAMAICA AVE                2
# 50060807          Chinese    2861 WHITE PLAINS RD                2
# 50060808           Bakery       21023 JAMAICA AVE                3
#
#                ...         liquor_license  sidewalk_license  \
# 30075445       ...                      L               NaN
# 30112340       ...                     OP               NaN
# 30191841       ...                     AX        Unenclosed
# 40356018       ...                     CT               NaN
# 40356151       ...                    NaN               NaN
# ...            ...                    ...               ...
# 50060427       ...                     OP          Enclosed
# 50060496       ...                    NaN               NaN
# 50060695       ...                    NaN               NaN
# 50060807       ...                     AX               NaN
# 50060808       ...                    NaN               NaN
#
#           food_poisoning_complaints  food_establishment_complaints  \
# 30075445                        2.0                            5.0
# 30112340                        5.0                            7.0
# 30191841                       16.0                           13.0
# 40356018                        0.0                            9.0
# 40356151                        0.0                            3.0
# ...                             ...                            ...
# 50060427                        3.0                           14.0
# 50060496                        0.0                            1.0
# 50060695                        0.0                            0.0
# 50060807                        3.0                            5.0
# 50060808                        0.0                            0.0
#
#           electric_complaints  safety_complaints  rodent_complaints  \
# 30075445                  3.0                1.0               24.0
# 30112340                 23.0                3.0               27.0
# 30191841                172.0               72.0               32.0
# 40356018                 24.0                4.0               13.0
# 40356151                  6.0                0.0                8.0
# ...                       ...                ...                ...
# 50060427                 14.0                2.0               83.0
# 50060496                  9.0                4.0                4.0
# 50060695                  0.0                0.0                1.0
# 50060807                 55.0               14.0               62.0
# 50060808                  0.0                0.0                1.0
#
#           dirty_conditions_complaints  missed_collection_complaints  \
# 30075445                         24.0                          20.0
# 30112340                         18.0                           4.0
# 30191841                         33.0                          26.0
# 40356018                          8.0                           3.0
# 40356151                         12.0                          20.0
# ...                               ...                           ...
# 50060427                         31.0                          13.0
# 50060496                         32.0                           3.0
# 50060695                          4.0                           3.0
# 50060807                         24.0                           9.0
# 50060808                          4.0                           3.0
#
#           complaints_null
# 30075445                0
# 30112340                0
# 30191841                0
# 40356018                0
# 40356151                0
# ...                   ...
# 50060427                0
# 50060496                0
# 50060695                0
# 50060807                0
# 50060808                0
#
# [22307 rows x 40 columns]

# %% [markdown]
# ## Drop columns that we know we don't want during training

# %%
violations_df2 = violations_df.drop(['address', 'crit_violations', 'earliest_inspection',
                                     'latest_inspection', 'second_latest_inspection',
                                     'non_crit_violations', 'num_inspections',
                                     'crit_violations_recent_inspect', 'non_crit_violations_recent_inspect',
                                     'complaints_null'], axis=1)
display(violations_df2)
# Out:
#           zipcode       boro          cuisine  crit_violations_train  \
# 30075445    10462      BRONX           Bakery                      7
# 30112340    11225   BROOKLYN       Hamburgers                     13
# 30191841    10019  MANHATTAN            Irish                      3
# 40356018    11224   BROOKLYN         American                      0
# 40356151    11369     QUEENS         American                     12
# ...           ...        ...              ...                    ...
# 50060427    11217   BROOKLYN  Bagels/Pretzels                      8
# 50060496    11232   BROOKLYN     Delicatessen                      4
# 50060695    11432     QUEENS            Pizza                      6
# 50060807    10467      BRONX          Chinese                      1
# 50060808    11428     QUEENS           Bakery                      7
#
#           non_crit_violations_train  num_inspections_train  \
# 30075445                          3                      4
# 30112340                          9                      8
# 30191841                          6                      4
# 40356018                          6                      3
# 40356151                          4                      6
# ...                             ...                    ...
# 50060427                          3                      2
# 50060496                          3                      1
# 50060695                          3                      1
# 50060807                          0                      1
# 50060808                          3                      2
#
#           average_crit_v_train  average_non_crit_v_train  \
# 30075445                 1.750                  0.750000
# 30112340                 1.625                  1.125000
# 30191841                 0.750                  1.500000
# 40356018                 0.000                  2.000000
# 40356151                 2.000                  0.666667
# ...                        ...                       ...
# 50060427                 4.000                  1.500000
# 50060496                 4.000                  3.000000
# 50060695                 6.000                  3.000000
# 50060807                 1.000                  0.000000
# 50060808                 3.500                  1.500000
#
#           time_since_last_inspection  time_since_first_inspection  \
# 30075445                         374                          918
# 30112340                          24                          875
# 30191841                         253                         1044
# 40356018                         346                         1076
# 40356151                         351                          764
# ...                              ...                          ...
# 50060427                          17                           30
# 50060496                          32                           32
# 50060695                           6                            6
# 50060807                          11                           11
# 50060808                           4                           18
#
#                       ...               rating_null_zip liquor_license  \
# 30075445              ...                             0              L
# 30112340              ...                             0             OP
# 30191841              ...                             0             AX
# 40356018              ...                             0             CT
# 40356151              ...                             0            NaN
# ...                   ...                           ...            ...
# 50060427              ...                             0             OP
# 50060496              ...                             0            NaN
# 50060695              ...                             0            NaN
# 50060807              ...                             0             AX
# 50060808              ...                             0            NaN
#
#           sidewalk_license  food_poisoning_complaints  \
# 30075445               NaN                        2.0
# 30112340               NaN                        5.0
# 30191841        Unenclosed                       16.0
# 40356018               NaN                        0.0
# 40356151               NaN                        0.0
# ...                    ...                        ...
# 50060427          Enclosed                        3.0
# 50060496               NaN                        0.0
# 50060695               NaN                        0.0
# 50060807               NaN                        3.0
# 50060808               NaN                        0.0
#
#           food_establishment_complaints  electric_complaints  \
# 30075445                            5.0                  3.0
# 30112340                            7.0                 23.0
# 30191841                           13.0                172.0
# 40356018                            9.0                 24.0
# 40356151                            3.0                  6.0
# ...                                 ...                  ...
# 50060427                           14.0                 14.0
# 50060496                            1.0                  9.0
# 50060695                            0.0                  0.0
# 50060807                            5.0                 55.0
# 50060808                            0.0                  0.0
#
#          safety_complaints rodent_complaints  dirty_conditions_complaints  \
# 30075445               1.0              24.0                         24.0
# 30112340               3.0              27.0                         18.0
# 30191841              72.0              32.0                         33.0
# 40356018               4.0              13.0                          8.0
# 40356151               0.0               8.0                         12.0
# ...                    ...               ...                          ...
# 50060427               2.0              83.0                         31.0
# 50060496               4.0               4.0                         32.0
# 50060695               0.0               1.0                          4.0
# 50060807              14.0              62.0                         24.0
# 50060808               0.0               1.0                          4.0
#
#           missed_collection_complaints
# 30075445                          20.0
# 30112340                           4.0
# 30191841                          26.0
# 40356018                           3.0
# 40356151                          20.0
# ...                                ...
# 50060427                          13.0
# 50060496                           3.0
# 50060695                           3.0
# 50060807                           9.0
# 50060808                           3.0
#
# [22307 rows x 30 columns]

# %% [markdown]
# ## What features do we have currently?

# %%
print(violations_df2.columns.values)
# Out:
# ['zipcode' 'boro' 'cuisine' 'crit_violations_train'
#  'non_crit_violations_train' 'num_inspections_train' 'average_crit_v_train'
#  'average_non_crit_v_train' 'time_since_last_inspection'
#  'time_since_first_inspection' 'crit_v_2plus' 'address2' 'latitude'
#  'longitude' '3day_temp' '3day_humidity' 'names' 'search_info' 'rating'
#  'rating_null' 'rating_null_zip' 'liquor_license' 'sidewalk_license'
#  'food_poisoning_complaints' 'food_establishment_complaints'
#  'electric_complaints' 'safety_complaints' 'rodent_complaints'
#  'dirty_conditions_complaints' 'missed_collection_complaints']

# %%
## Normalize numerical features # Work in progress

def feature_normalization(train, test): # From first homework assignment
    """Rescale the data so that each feature in the training set is in
    the interval [0,1], and apply the same transformations to the test
    set, using the statistics computed on the training set.

    Args:
        train - training set, a 2D numpy array of size (num_instances, num_features)
        test  - test set, a 2D numpy array of size (num_instances, num_features)
    Returns:
        train_normalized - training set after normalization
        test_normalized  - test set after normalization

    """
    m = np.min(train,axis=0)
    M = np.max(train,axis=0)
    train_normalized = (train - m)/(M-m)
    test_normalized = (test - m)/(M-m)
    return train_normalized, test_normalized
